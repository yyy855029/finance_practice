# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#設定字體和解決圖像中文顯示問題
plt.rcParams['font.sans-serif']=['Microsoft JhengHei']
plt.rcParams['axes.unicode_minus']=False

st=np.linspace(10500,11300,1000)
k1=10800
k2=10900
k3=11000

c1=np.maximum(st-k1,0)-152
c2=np.maximum(st-k2,0)-95
c3=np.maximum(st-k3,0)-50
profit=c1+c3-2*c2

fig,ax=plt.subplots(1,figsize=(10,5))
ax.plot(st,profit,label='Profit')
ax.plot(st,c1,linestyle='--',label='Long C1 (152)')
ax.plot(st,-2*c2,linestyle='--',label='Short 2C2 (93)')
ax.plot(st,c3,linestyle='--',label='Long C3 (50)')
ax.spines['bottom'].set_position(('data',0))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_title('買進蝶式策略',fontsize=18)
ax.tick_params(axis='y',labelsize=8)
ax.tick_params(axis='x',labelsize=8)
ax.set_xlim(10500,11300)
ax.set_ylim(-600,600)
ax.set_xticks(np.arange(10600,11300,100))
ax.legend(bbox_to_anchor=(1.01,1), loc='upper left')
ax.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#設定字體和解決圖像中文顯示問題
plt.rcParams['font.sans-serif']=['Microsoft JhengHei']
plt.rcParams['axes.unicode_minus']=False

st=np.linspace(10700,11400,300)
k1=10900
k2=11100
c1=np.maximum(st-k1,0)-50
c2=np.maximum(st-k2,0)-12
profit=c1-c2

fig,ax=plt.subplots(1,figsize=(10,5))
ax.plot(st,profit,label='Profit')
ax.plot(st,c1,linestyle='--',label='Long C1 (50)')
ax.plot(st,-c2,linestyle='--',label='Short C2 (12)')
ax.spines['bottom'].set_position(('data',0))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_title('買權多頭價差策略',fontsize=18)
ax.tick_params(axis='y',labelsize=8)
ax.tick_params(axis='x',labelsize=8)
ax.set_ylim(-300,300)
ax.set_xlim(10700,11400)
ax.set_xticks(np.arange(10800,11400,100))
ax.grid()
ax.legend(bbox_to_anchor=(1.01,1),loc='upper left')

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#設定字體和解決圖像中文顯示問題
plt.rcParams['font.sans-serif']=['Microsoft JhengHei']
plt.rcParams['axes.unicode_minus']=False

st=np.linspace(10700,11100,300)
k=10900
c=np.maximum(k-st,0)-50

fig,ax=plt.subplots(1,figsize=(10,5))
ax.plot(st,c,linestyle='-',label='Long Put(K=10900)')
ax.spines['bottom'].set_position(('data',0))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_title('買進賣權策略',fontsize=18)
ax.legend(bbox_to_anchor=(1.01,1),loc='upper left',fontsize=12)
ax.tick_params(axis='y',labelsize=8)
ax.tick_params(axis='x',labelsize=8)
ax.set_ylim(-75,150)
ax.set_xticks(np.arange(10700,11200,100))
ax.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#設定字體和解決圖像中文顯示問題
plt.rcParams['font.sans-serif']=['Microsoft JhengHei']
plt.rcParams['axes.unicode_minus']=False

st=np.linspace(5.85,6.45,300)
profit=np.where(st<6.15,(6.15-st)*2000,(6.15-st)*2*2000)

fig,ax=plt.subplots(1,figsize=(10,5))
ax.plot(st,profit,label='損益',color='#1f77b4')
ax.spines['bottom'].set_position(('data',0))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_title('TRF無保護區間損益圖',fontsize=18)
ax.legend(bbox_to_anchor=(1.01,1),loc='upper left',fontsize=12)
ax.tick_params(axis='y',labelsize=9)
ax.tick_params(axis='x',labelsize=9)
ax.set_yticks(np.arange(-1400,900,200))
ax.set_xticks(np.arange(5.9,6.5,0.05))
ax.set_ylim(-1400,800)
ax.set_xlim(5.85,6.45)
ax.set_xlabel('USD/CHN匯率',fontsize=11)
ax.xaxis.set_label_coords(0.99,0.7)
ax.set_ylabel('損益:千人民幣',fontsize=11)
ax.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#設定字體和解決圖像中文顯示問題
plt.rcParams['font.sans-serif']=['Microsoft JhengHei']
plt.rcParams['axes.unicode_minus']=False

st1=np.linspace(5.915,6.18,500)
profit1=np.where(st1<6.115,(6.115-st1)*2000,0)
st2=np.linspace(6.18,6.34,500)
profit2=(6.115-st2)*2*2000

fig,ax=plt.subplots(1,figsize=(10,5))
ax.plot(st1,profit1,label='損益',color='#1f77b4')
ax.plot(st2,profit2,label='損益',color='#1f77b4')
ax.spines['bottom'].set_position(('data',0))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_title('TRF有保護區間損益圖',fontsize=18)
ax.legend(['損益'],bbox_to_anchor=(1.01,1),loc='upper left',fontsize=12)
ax.tick_params(axis='y',labelsize=9)
ax.tick_params(axis='x',labelsize=9)
ax.set_xticks([5.955,5.995,6.035,6.075,6.115,6.18,6.22,6.26,6.3,6.34])
ax.set_ylim(-1000,600)
ax.set_xlim(5.915,6.34)
ax.set_xlabel('USD/CHN匯率',fontsize=11)
ax.xaxis.set_label_coords(0.99,0.7)
ax.set_ylabel('損益:千人民幣',fontsize=11)
ax.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#設定字體和解決圖像中文顯示問題
plt.rcParams['font.sans-serif']=['Microsoft JhengHei']
plt.rcParams['axes.unicode_minus']=False

st1=np.linspace(5.915,6.18,500)
st2=np.linspace(6.18,6.34,500)
st=np.append(st1,st2)

k1=6.115
k2=6.18
c=2000*np.maximum(st-k1,0)
p=2000*np.maximum(k1-st,0)
cu1=2000*np.maximum(st1-k1,0)
cu2=(6.18-6.115)*np.zeros(500)*2000
cu=np.append(cu1,cu2)
profit=p-2*c+2*cu

fig,ax=plt.subplots(1,figsize=(10,5))
ax.plot(st,profit,label='損益')
ax.plot(st,2*cu,label='Long 2Cu',linestyle='--')
ax.plot(st,p,label='Long P',linestyle='--')
ax.plot(st,-2*c,label='Short 2C',linestyle='--')
ax.spines['bottom'].set_position(('data',0))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_title('TRF無保護區間損益圖',fontsize=18)
ax.legend(bbox_to_anchor=(1.01,1),loc='upper left',fontsize=12)
ax.tick_params(axis='y',labelsize=9)
ax.tick_params(axis='x',labelsize=9)
ax.set_xticks([5.955,5.995,6.035,6.075,6.115,6.18,6.22,6.26,6.3,6.34])
ax.set_ylim(-1000,600)
ax.set_xlim(5.915,6.34)
ax.set_xlabel('USD/CHN匯率',fontsize=11)
ax.xaxis.set_label_coords(0.99,0.55)
ax.set_ylabel('損益:千人民幣',fontsize=11)
ax.grid()

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter,FormatStrFormatter
# %matplotlib inline

#設定字體和解決圖像中文顯示問題
plt.rcParams['font.sans-serif']=['Microsoft JhengHei']
plt.rcParams['axes.unicode_minus']=False

#利用numpy和scipy
def future_bs(S,K,r,T,sigma):
    d1=(np.log(S/K)+(0.5*sigma**2)*T)/(sigma*np.sqrt(T))
    d2=d1-sigma*np.sqrt(T)
    C=np.exp(-r*T)*(S*norm.cdf(d1)-K*norm.cdf(d2))
    return C

st=np.linspace(11200,12200,1001)
k=11600
c=np.maximum(st-k,0)-133
ct=np.array([future_bs(S,11600,0.008731,7/365,0.1149)-133 for S in st])
profit=1490*50*(ct-1)

fig,axes=plt.subplots(2,figsize=(10,10))
axes[0].plot(st,c,linestyle='-',label='內含價值')
axes[0].plot(st,ct,linestyle='-',label='內含價值+時間價值')
axes[0].spines['bottom'].set_position(('data',0))
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].set_title('買進買權策略',fontsize=18)
axes[0].tick_params(axis='y',labelsize=8)
axes[0].tick_params(axis='x',labelsize=8)
axes[0].set_ylim(-200,400)
axes[0].set_xlim(11200,12200)
axes[0].set_xticks(np.arange(11300,12200,100))
axes[0].grid()
axes[0].legend(bbox_to_anchor=(1.01,1),loc='upper left',fontsize=12)


axes[1].plot(st,profit,label='損益')
axes[1].spines['bottom'].set_position(('data',0))
axes[1].spines['top'].set_visible(False)
axes[1].spines['right'].set_visible(False)
axes[1].set_title('預期下週損益',fontsize=18)
axes[1].yaxis.set_major_formatter(FormatStrFormatter('%.0f'))
axes[1].tick_params(axis='y',labelsize=8)
axes[1].tick_params(axis='x',labelsize=8)
axes[1].set_xlim(11200,12200)
axes[1].set_xticks(np.arange(11300,12200,100))
axes[1].grid()
axes[1].legend(bbox_to_anchor=(1.01,1),loc='upper left',fontsize=12)

#negative:True,positive:False
negative=profit<0
#profit負值個數
print('負值共有{}個，從編號0到{}'.format(negative.sum(),(negative.sum()-1)),'\n')

#st
print('最後一個出現負值的股價是編號{}，股價:{}'.format((negative.sum()-1),st[negative.sum()-1]))
print('第一個出現正值的股價是編號{}，股價:{}'.format((negative.sum()),st[negative.sum()]),'\n')

#profit
print('最後一個出現負值的損益是編號{}，損益:{}'.format((negative.sum()-1),profit[negative.sum()-1]))
print('第一個出現正值的損益是編號{}，損益:{}'.format((negative.sum()),profit[negative.sum()]),'\n')
# Out:
# 負值共有500個，從編號0到499
#
# 最後一個出現負值的股價是編號499，股價:11699.0
# 第一個出現正值的股價是編號500，股價:11700.0
#
# 最後一個出現負值的損益是編號499，損益:-20120.970839394515
# 第一個出現正值的損益是編號500，損益:32543.797999373666

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
# %matplotlib inline

#設定字體和解決圖像中文顯示問題
plt.rcParams['font.sans-serif']=['Microsoft JhengHei']
plt.rcParams['axes.unicode_minus']=False

spread=np.linspace(0,0.3,2000)
profit=10000*np.where(spread<0.1023,np.maximum(0,spread/0.1023),1)+350.4

fig,ax=plt.subplots(1,figsize=(10,5))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.plot(spread,profit,label='到期贖回金額+配息金額')
ax.plot(spread,350.4*np.ones(len(spread)),label='配息金額',linestyle='--')
ax.plot(spread,10000*np.where(spread<0.1023,np.maximum(0,spread/0.1023),1),label='到期贖回金額',linestyle='--')
ax.set_title('該商品到期收益圖',fontsize=16)
ax.set_xlim(0,0.3)
ax.set_ylim(0,12000)
ax.set_xlabel('利差(%)',fontsize=12)
ax.set_ylabel('總收益:美元',fontsize=12)
ax.set_xticks([0,0.05,0.1023,0.15,0.2,0.25,0.3])
ax.set_yticks([350.4,2000,4000,6000,8000,10000,10350.4,12000])
ax.xaxis.set_major_formatter(FormatStrFormatter('%.4f'))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
ax.tick_params(axis='y',labelsize=9)
ax.tick_params(axis='x',labelsize=9)
ax.legend(bbox_to_anchor=(1.01,1),loc='upper left',fontsize=11)
ax.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
# %matplotlib inline

#設定字體和解決圖像中文顯示問題
plt.rcParams['font.sans-serif']=['Microsoft JhengHei']
plt.rcParams['axes.unicode_minus']=False


spread=np.linspace(0,0.3,2000)
profit=10000*np.where(spread<0.1023,np.maximum(0,spread/0.1023),1)+350.4
returns=((profit/10000)-1)*100


fig,ax=plt.subplots(1,figsize=(12,5))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.plot(spread,returns,label='報酬率')
ax.set_title('該商品到期6個月報酬率(%)圖',fontsize=16)
ax.set_xlim(0,0.3)
ax.set_ylim(-100,10)
ax.set_xlabel('利差(%)',fontsize=12)
ax.set_yticks([-96.496,-80,-60,-20,0,3.504])
ax.set_xticks([0,0.05,0.09872,0.1023,0.15,0.2,0.25,0.3])
ax.set_xticklabels([0,0.05,0.09872,0.1023,0.15,0.2,0.25,0.3],rotation=90)
ax.xaxis.set_major_formatter(FormatStrFormatter('%.5f'))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.3f'))
ax.tick_params(axis='y',labelsize=9)
ax.tick_params(axis='x',labelsize=8)
ax.grid()

# %%
from io import StringIO
import requests
from datetime import datetime,timedelta
import numpy as np
import pandas as pd
from pandas.plotting import register_matplotlib_converters
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import matplotlib.dates as mdates
# %matplotlib inline

register_matplotlib_converters()
#設定字體和解決圖像中文顯示問題
plt.rcParams['font.sans-serif']=['Microsoft JhengHei']
plt.rcParams['axes.unicode_minus']=False

#定義爬取FRED價格資料函數
def fred_price_crawler(ids,startdate,enddate):
    startdate=startdate.strftime('%Y-%m-%d')
    enddate=enddate.strftime('%Y-%m-%d')
    url='https://fred.stlouisfed.org/graph/fredgraph.csv?id={}&cosd={}&coed={}'.format(ids,startdate,enddate)
    response=requests.get(url)
    df=pd.read_csv(StringIO(response.text))
    df[ids]=pd.to_numeric(df[ids],errors='coerce')
    df['DATE']=pd.to_datetime(df['DATE'])
    
    return df

enddate=datetime.now().date()
startdate=(enddate-timedelta(days=365*5))

rate_30=fred_price_crawler('DGS30',startdate,enddate)
rate_2=fred_price_crawler('DGS2',startdate,enddate)
rate=pd.merge(rate_30,rate_2,on='DATE')
rate['DIFF']=rate['DGS30']-rate['DGS2']
rate.set_index('DATE',inplace=True)


fig,axes=plt.subplots(2,figsize=(12,10))
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].plot(rate.index,rate['DGS2'],label='2年期美國公債殖利率(%)')
axes[0].plot(rate.index,rate['DGS30'],label='30年期美國公債殖利率(%)')
axes[0].axvline('2018-01-31',linestyle='--',color='dimgray')
axes[0].axvline('2018-07-31',linestyle='--',color='dimgray')
axes[0].fill_between(['2018-01-31','2018-07-31'],0,3.5,color='gray',alpha=0.1)
axes[0].set_title('美國公債殖利率(%)走勢圖',fontsize=15)
axes[0].legend(bbox_to_anchor=(1.01,1),loc='upper left',fontsize=11)
axes[0].xaxis.set_major_locator(mdates.MonthLocator(interval=6))
axes[0].tick_params(axis='x',labelsize=8)
axes[0].set_ylim(0,3.5)
axes[0].grid()

axes[1].spines['top'].set_visible(False)
axes[1].spines['right'].set_visible(False)
axes[1].plot(rate.index,rate['DIFF'],color='g')
axes[1].axhline(0.1023,linestyle='--',color='r')
axes[1].axvline('2018-01-31',linestyle='--',color='dimgray')
axes[1].axvline('2018-07-31',linestyle='--',color='dimgray')
axes[1].fill_between(['2018-01-31','2018-07-31'],0,3.5,color='gray',alpha=0.1)
axes[1].set_title('美國公債殖利率利差(%)走勢圖',fontsize=15)
axes[1].set_ylim(0,3.5)
axes[1].set_yticks([0.1023,0.5,1,1.5,2,2.5,3,3.5])
axes[1].yaxis.set_major_formatter(FormatStrFormatter('%.4f'))
axes[1].xaxis.set_major_locator(mdates.MonthLocator(interval=6))
axes[1].tick_params(axis='x',labelsize=8)
axes[1].grid()

plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
# %matplotlib inline

ceti=np.linspace(0,15,1000)
k=5.125
payoff=np.where(ceti>=5.125,7.5,-43.75+10*ceti)

fig,ax=plt.subplots(1,figsize=(8,5))
ax.plot(ceti,payoff)
ax.plot([5.125,5.125],[0,7.5],linestyle='--',color='gray')
ax.plot([0,5.125],[7.5,7.5],linestyle='--',color='gray')
ax.spines['bottom'].set_position(('data',0))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xlabel('CETI Ratio(%)',fontsize=11)
ax.set_ylabel('Payoff(%)',fontsize=11,rotation=0)
ax.yaxis.set_label_coords(-0.06,0.99)
ax.xaxis.set_label_coords(0.95,0.6)
ax.tick_params(axis='y',labelsize=10)
ax.tick_params(axis='x',labelsize=10)
ax.set_ylim(-50,30)
ax.set_xlim(0,12)
ax.set_yticks([0,7.5])
ax.set_xticks([5.125])
ax.xaxis.set_major_formatter(FormatStrFormatter('%.3f'))
